# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader, WeightedRandomSampler
from torch.cuda.amp import autocast, GradScaler

import numpy as np

from torchvision import datasets, transforms

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

import random
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# %%
transform = transforms.Compose([transforms.ToTensor()])

train_ds = datasets.MNIST('.', train=True,transform=transform,download=True)
test_ds = datasets.MNIST('.', train = False, download=True, transform=transform)

# %%
## for imbalance data
lables = np.array(train_ds.targets)
print(lables)
print(len(lables))

class_counts = np.bincount(lables)
print(class_counts)

class_weights = 1.0 / ( class_counts + 1e-6)
print(class_weights)

sample_weights = class_weights[lables]
print(sample_weights)

sampler = WeightedRandomSampler(sample_weights, num_samples= len(sample_weights), replacement=True)
# Out:
# [5 0 4 ... 5 6 8]
# 60000
# [5923 6742 5958 6131 5842 5421 5918 6265 5851 5949]
# [0.00016883 0.00014832 0.00016784 0.00016311 0.00017117 0.00018447
#  0.00016898 0.00015962 0.00017091 0.0001681 ]
# [0.00018447 0.00016883 0.00017117 ... 0.00018447 0.00016898 0.00017091]
# /var/folders/c8/68n9_s8d6sxg8pl5bmt94v180000gn/T/ipykernel_77001/102830970.py:2: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   lables = np.array(train_ds.targets)

# %%
train_loader = DataLoader(train_ds, batch_size=64, sampler=sampler)
test_loader = DataLoader(test_ds,   batch_size=64, shuffle=False)

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Conv2d(in_channels=1,out_channels=32,kernel_size=3,padding=1)
        self.rel = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=32,out_channels=64,kernel_size=3,padding=1)
        self.rel = nn.ReLU()
        self.pooling = nn.MaxPool2d(2)
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(64*14*14,10)



    def forward(self, x):
        print(x.shape)
        x = self.conv1(x)
        print(x.shape)
        x = self.rel(x) 
        print(x.shape)
        x = self.conv2(x)
        print(x.shape)
        x = self.rel(x)
        print(x.shape)
        x = self.pooling(x)
        print(x.shape)
        x = self.flatten(x)
        print(x.shape)
        x = self.linear(x)
        print(x.shape)
        return x





model = SimpleCNN().to(device)






class FocalLoss(nn.Module):
    def  __init__(self, gamma=2.0, weight = None , reduction = 'mean'):
        super().__init__()   
        self.gamma, self.weight, self.reduction = gamma , weight, reduction

    def forward(self,logits,target):
        ce = nn.functional.cross_entropy(logits,target,weight=self.weight,reduction=self.reduction)
        pt = torch.exp(-ce)
        loss = ((1-pt)**self.gamma)*ce
        return loss.mean() if self.reduction=='mean' else loss.sum
    






criterion = FocalLoss()

optimizer = optim.Adam(model.parameters(),lr = 0.001)
scaler = GradScaler()








for epoch in range(3):
    model.train()
    for x, gt in train_loader:
        
        x = x.to(device)
        gt = gt.to(device)

        optimizer.zero_grad()
    
        with autocast():
            logits = model(x)
            loss = criterion(logits, gt)
        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        scaler.step(optimizer)
        scaler.update() 
        print(f"Epoch: {epoch}, Loss: {loss}")
        

        checkpoint = {
            'epoch': epoch,
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scaler':scaler.state_dict(),
            'loss':loss
        }

        torch.save(checkpoint,'checkpoint.pth')

    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for x , gt in test_loader:
            x, gt = x.to(device), gt.to(device)
            preds = model(x).argmax(1)
            correct += (preds == gt).sum().item()
            total += gt.size(0)
    print(f"Epoch {epoch}: acc {correct/total:.4f}")
# Out:
# /var/folders/c8/68n9_s8d6sxg8pl5bmt94v180000gn/T/ipykernel_77001/1532060885.py:64: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /var/folders/c8/68n9_s8d6sxg8pl5bmt94v180000gn/T/ipykernel_77001/1532060885.py:82: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 1.8573946952819824
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 2.151101589202881
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 1.8608241081237793
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 1.703195571899414
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 1.5971957445144653
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 1.4357458353042603
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 1.3527886867523193
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 1.2167714834213257
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.9615530371665955
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.7497453093528748
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.6987060308456421
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.5572987198829651
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.49087798595428467
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.3911007344722748
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.2953522801399231
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.24127230048179626
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.17673662304878235
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.1875503957271576
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.22219029068946838
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.1405157446861267
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.2058207243680954
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.12830492854118347
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.3483167588710785
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.20788758993148804
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.08392074704170227
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.08183639496564865
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.1315300315618515
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.13155902922153473
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.07645262032747269
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.09940681606531143
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.037613436579704285
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.05478706583380699
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.05701185762882233
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.019496699795126915
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.11909568309783936
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.04018281400203705
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.09557336568832397
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.017131395637989044
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.029539845883846283
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03749965876340866
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.06177298352122307
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.0320146419107914
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.030690880492329597
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.10229399800300598
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.10928626358509064
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.016152802854776382
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.07947643846273422
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.05498499423265457
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.04302919656038284
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.11130727827548981
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.024574995040893555
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.021628176793456078
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.038673922419548035
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.053376488387584686
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03507247194647789
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.01295323297381401
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.02274153009057045
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.05621539428830147
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.10980940610170364
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.043995533138513565
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.07148019224405289
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.05874430388212204
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.004118543583899736
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.06278474628925323
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.016274824738502502
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.031074276193976402
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.0096414964646101
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.011148395948112011
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.04508623853325844
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.011471424251794815
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.020320896059274673
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.029051663354039192
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.05390387773513794
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.10634580254554749
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.008363308385014534
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.01880045421421528
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.022989964112639427
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.02089827135205269
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.033083535730838776
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.1295524388551712
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.07468675822019577
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.04724114015698433
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.003844639752060175
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.062078095972537994
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.01205419935286045
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03972596302628517
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.004996970295906067
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03703448548913002
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.020384037867188454
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.011157272383570671
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.02108094096183777
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.01023250911384821
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.04666383937001228
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.021421756595373154
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.06918887794017792
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.036219362169504166
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03353702276945114
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.02291768416762352
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.07584171742200851
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03483365476131439
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03216473013162613
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.013251733966171741
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03922764211893082
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.034454312175512314
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.0013329125940799713
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.004991552326828241
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.020826412364840508
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.007277505472302437
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03972320631146431
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.05572301894426346
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.005144708789885044
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.011183701455593109
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.01594061218202114
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.03253970295190811
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.021649496629834175
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.013205754570662975
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.05571912229061127
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.005638067610561848
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.08229034394025803
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.01630547270178795
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.06998318433761597
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.008574437350034714
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.006345234811306
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.005817687138915062
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.015277762897312641
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.009205025620758533
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.012043951079249382
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 28, 28])
# torch.Size([64, 64, 14, 14])
# torch.Size([64, 12544])
# torch.Size([64, 10])
# Epoch: 0, Loss: 0.031698085367679596
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 32, 28, 28])
# torch.Size([64, 32, 28, 28])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 83
#      80 optimizer.zero_grad()
#      82 with autocast():
# ---> 83     logits = model(x)
#      84     loss = criterion(logits, gt)
#      85 scaler.scale(loss).backward()
#
# File ~/my-code/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/my-code/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# Cell In[7], line 21, in SimpleCNN.forward(self, x)
#      19 x = self.rel(x)
#      20 print(x.shape)
# ---> 21 x = self.conv2(x)
#      22 print(x.shape)
#      23 x = self.rel(x)
#
# File ~/my-code/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/my-code/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/my-code/.venv/lib/python3.13/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/my-code/.venv/lib/python3.13/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
