# %%
import albumentations as A
import glob
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
train_images = glob.glob('../voc_2012_segmentation_data/train_images/*')
train_masks = glob.glob('../voc_2012_segmentation_data/train_labels/*')

train_images.sort()
train_masks.sort()

# %%
train_image_transform = A.Compose([
#     A.Resize(img_size, img_size, always_apply=True),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.25),
    A.Rotate(limit=25)
])

# %%
for i in range(10):
    print(train_images[i])
    image = np.array(Image.open(train_images[i]).convert('RGB'))
    mask = np.array(Image.open(train_masks[i]).convert('RGB'))
    
    transformed = train_image_transform(image=image, mask=mask)
    image = transformed['image']
    mask = transformed['mask']
    
    plt.figure(figsize=(12, 9))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.imshow(mask)
    plt.axis('off')
    plt.show()
# Out:
# ../voc_2012_segmentation_data/train_images/2007_000032.jpg
# ../voc_2012_segmentation_data/train_images/2007_000039.jpg
# ../voc_2012_segmentation_data/train_images/2007_000063.jpg
# ../voc_2012_segmentation_data/train_images/2007_000068.jpg
# ../voc_2012_segmentation_data/train_images/2007_000121.jpg
# ../voc_2012_segmentation_data/train_images/2007_000170.jpg
# ../voc_2012_segmentation_data/train_images/2007_000241.jpg
# ../voc_2012_segmentation_data/train_images/2007_000243.jpg
# ../voc_2012_segmentation_data/train_images/2007_000250.jpg
# ../voc_2012_segmentation_data/train_images/2007_000256.jpg
